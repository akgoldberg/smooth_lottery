# %%
from algorithm.full_LP import *
import pandas as pd
import numpy as np
from algorithm.helpers import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from algorithm.full_LP import *
#       2 import pandas as pd
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'algorithm'

# %%
def summarize_p(p):
    # Num accepted
    p_round = np.round(p, 2)
    num_accepted = np.sum(p_round == 1)
    num_rejected = np.sum(p_round == 0)
    print(f"Accepted: {num_accepted} intervals")
    print(f"Randomized: {len(p) - (num_accepted + num_rejected)} intervals")
    print(f"Rejected: {num_rejected} intervals")

    print("")

    p_counts = np.unique(p_round, return_counts=True)
    # print count of each p_i in decreasing order of p_i
    for i in list(range(len(p_counts[0])))[::-1]:
        print(f"p = {p_counts[0][i]}: {p_counts[1][i]} intervals")

# %% [markdown]
# ### Swiss NSF Intervals

# %%
# load Swiss NSF data from csv 
df = pd.read_csv('data/SwissNSFData/intervals.csv')
df.sort_values(by='m', ascending=True, inplace=True) # lower is better for Swiss NSF (ranked by expectd rank)
df.reset_index(drop=True, inplace=True)
n = df.shape[0]
intervals = list(zip(n - df['h'], n - df['l'])) # make list of intervals, l = n - ER, h = n ER using using 50% CI
intervals90 = list(zip(n - df['hh'], n - df['ll'])) # make list of intervals, l = n - ER, h = n ER using 90% CI
x = list(n - df['m'])

# %%
plot_intervals(intervals)
plt.show()

# %%
k = 106
pruned, top, bottom = prune_instance(intervals, k)
pruned_intervals = [intervals[i] for i in pruned]
print("Accept {} intervals".format(len(top)))
print("Reject {} intervals".format(len(bottom)))
print("Remaining {} intervals".format(len(pruned)))
n_partitions = len(partition_intervals(intervals))
n_partitions_pruned = len(partition_intervals(pruned_intervals))
print("Number of partitions: {}".format(n_partitions))
print("Number of partitions pruned: {}".format(n_partitions_pruned))
# plot pruned intervals
plot_intervals(pruned_intervals)
plt.show()
# Out:
# Accept 89 intervals
# Reject 223 intervals
# Remaining 41 intervals
# Number of partitions: 2
# Number of partitions pruned: 1

# %%
v, p = solve_instance_unordered(intervals, k, k)
p_swiss = swiss_nsf(intervals, x, k)
# Out:
# Solving instance with n=353, k=106.
# Pruned 312 intervals. Solving with n=41, k=17.
# Solving with 99 constraints.
# Solved with optimal value: 10.999999999903595 out of 17.
# Finished post-processing solution.

# %%
vseq, pseq = solve_sequence(intervals, k, postprocess=True, lex_order_p=0, verbose=True, check_monotonicity=True, return_seq=True)
# Out:
# Solving instance with n=353, k=1.
# Pruned 346 intervals. Solving with n=7, k=1.
# Solving with 15 constraints.
# Solved with optimal value: 0.14285714251539072 out of 1.
# Finished post-processing solution.
# Solving instance with n=353, k=2.
# Pruned 346 intervals. Solving with n=7, k=2.
# Solving with 23 constraints.
# Solved with optimal value: 0.5714285714514732 out of 2.
# Finished post-processing solution.
# Solving instance with n=353, k=3.
# Pruned 346 intervals. Solving with n=7, k=3.
# Solving with 24 constraints.
# Solved with optimal value: 1.2857142857522488 out of 3.
# Finished post-processing solution.
# Solving instance with n=353, k=4.
# Pruned 346 intervals. Solving with n=7, k=4.
# Solving with 25 constraints.
# Solved with optimal value: 2.285714285721336 out of 4.
# Finished post-processing solution.
# Solving instance with n=353, k=5.
# Pruned 346 intervals. Solving with n=7, k=5.
# Solving with 26 constraints.
# Solved with optimal value: 3.571428571424896 out of 5.
# Finished post-processing solution.
# Solving instance with n=353, k=6.
# Pruned 342 intervals. Solving with n=11, k=6.
# Solving with 39 constraints.
# Solved with optimal value: 4.571428571669625 out of 6.
# Finished post-processing solution.
# Solving instance with n=353, k=7.
# Pruned 343 intervals. Solving with n=10, k=2.
# Solving with 32 constraints.
# Solved with optimal value: 0.2857142857394435 out of 2.
# Finished post-processing solution.
# Solving instance with n=353, k=8.
# Pruned 336 intervals. Solving with n=17, k=3.
# Solving with 54 constraints.
# Solved with optimal value: 0.9795918367378735 out of 3.
# Finished post-processing solution.
# Solving instance with n=353, k=9.
# Pruned 336 intervals. Solving with n=17, k=4.
# Solving with 55 constraints.
# Solved with optimal value: 1.5510204081718668 out of 4.
# Finished post-processing solution.
# Solving instance with n=353, k=10.
# Pruned 336 intervals. Solving with n=17, k=5.
# Solving with 56 constraints.
# Solved with optimal value: 2.13469387755108 out of 5.
# Finished post-processing solution.
# Solving instance with n=353, k=11.
# Pruned 337 intervals. Solving with n=16, k=5.
# Solving with 53 constraints.
# Solved with optimal value: 1.6511186188079425 out of 5.
# Finished post-processing solution.
# Solving instance with n=353, k=12.
# Pruned 337 intervals. Solving with n=16, k=6.
# Solving with 54 constraints.
# Solved with optimal value: 2.3162770973832316 out of 6.
# Finished post-processing solution.
# Solving instance with n=353, k=13.
# Pruned 337 intervals. Solving with n=16, k=7.
# Solving with 55 constraints.
# Solved with optimal value: 3.1030927834996658 out of 7.
# Finished post-processing solution.
# Solving instance with n=353, k=14.
# Pruned 337 intervals. Solving with n=16, k=8.
# Solving with 56 constraints.
# Solved with optimal value: 4.000000000023187 out of 8.
# Finished post-processing solution.
# Solving instance with n=353, k=15.
# Pruned 338 intervals. Solving with n=15, k=8.
# Solving with 53 constraints.
# Solved with optimal value: 4.247501188301019 out of 8.
# Finished post-processing solution.
# Solving instance with n=353, k=16.
# Pruned 337 intervals. Solving with n=16, k=9.
# Solving with 57 constraints.
# Solved with optimal value: 5.1428571428599925 out of 9.
# Finished post-processing solution.
# Solving instance with n=353, k=17.
# Pruned 337 intervals. Solving with n=16, k=10.
# Solving with 58 constraints.
# Solved with optimal value: 6.385542168643492 out of 10.
# Finished post-processing solution.
# Solving instance with n=353, k=18.
# Pruned 337 intervals. Solving with n=16, k=11.
# Solving with 59 constraints.
# Solved with optimal value: 7.7647058817783705 out of 11.
# Finished post-processing solution.
# Solving instance with n=353, k=19.
# Pruned 337 intervals. Solving with n=16, k=12.
# Solving with 60 constraints.
# Solved with optimal value: 9.283018867901607 out of 12.
# Finished post-processing solution.
# Solving instance with n=353, k=20.
# Pruned 328 intervals. Solving with n=25, k=13.
# Solving with 88 constraints.
# Solved with optimal value: 10.857142857142758 out of 13.
# Finished post-processing solution.
# Solving instance with n=353, k=21.
# Pruned 328 intervals. Solving with n=25, k=14.
# Solving with 89 constraints.
# Solved with optimal value: 11.857142857193775 out of 14.
# Finished post-processing solution.
# Solving instance with n=353, k=22.
# Pruned 335 intervals. Solving with n=18, k=7.
# Solving with 61 constraints.
# Solved with optimal value: 4.273332252795316 out of 7.
# Finished post-processing solution.
# Solving instance with n=353, k=23.
# Pruned 337 intervals. Solving with n=16, k=4.
# Solving with 52 constraints.
# Solved with optimal value: 0.7644430031923496 out of 4.
# Finished post-processing solution.
# Solving instance with n=353, k=24.
# Pruned 330 intervals. Solving with n=23, k=5.
# Solving with 74 constraints.
# Solved with optimal value: 1.4555537540674157 out of 5.
# Finished post-processing solution.
# Solving instance with n=353, k=25.
# Pruned 330 intervals. Solving with n=23, k=6.
# Solving with 75 constraints.
# Solved with optimal value: 2.249999999992658 out of 6.
# Finished post-processing solution.
# Solving instance with n=353, k=26.
# Pruned 330 intervals. Solving with n=23, k=7.
# Solving with 76 constraints.

# %%
verify_posthoc_validity(intervals, p)
# Out:
# True

# %%
valid = [verify_posthoc_validity(intervals, p) for p in pseq]
1. * sum(valid) / len(valid)
# Out:
# 1.0

# %%
summarize_p(pseq[-1])
# Out:
# Accepted: 100 intervals
# Randomized: 12 intervals
# Rejected: 241 intervals
#
# p = 1.0: 100 intervals
# p = 0.62: 1 intervals
# p = 0.6: 1 intervals
# p = 0.59: 1 intervals
# p = 0.58: 1 intervals
# p = 0.57: 1 intervals
# p = 0.56: 1 intervals
# p = 0.55: 1 intervals
# p = 0.54: 1 intervals
# p = 0.53: 1 intervals
# p = 0.49: 1 intervals
# p = 0.26: 1 intervals
# p = 0.1: 1 intervals
# p = 0.0: 241 intervals

# %%
summarize_p(p_swiss)
# Out:
# Accepted: 99 intervals
# Randomized: 13 intervals
# Rejected: 241 intervals
#
# p = 1.0: 99 intervals
# p = 0.54: 13 intervals
# p = 0.0: 241 intervals

# %%
n_top = len(top)
pct_swiss = np.round((evaluate_p([(l/2., u/2.) for (l,u) in intervals],p_swiss, k) - n_top) / (k-n_top), 3)
pct_opt = np.round((evaluate_p([(l/2., u/2.) for (l,u) in intervals], p, k) - n_top) / (k-n_top), 3)
pct_opt_monotonic = np.round((evaluate_p([(l/2., u/2.) for (l,u) in intervals], pseq[-1], k) - n_top) / (k-n_top), 3)
pct_topk = np.round((evaluate_p([(l/2., u/2.) for (l,u) in intervals],[1]*k+[0]*(n-k), k) - n_top) / (k-n_top), 3)

print(f"Always select {n_top}, {k-n_top} intervals left to optimize.")
print("Proportion of top-k intervals selected in worst case:")
print(f"Optimal: {pct_opt}")
print(f"Optimal w/ Monotonic: {pct_opt_monotonic}")
print(f"Swiss: {pct_swiss}")
print(f"Top-k: {pct_topk}")
# Out:
# Always select 89, 17 intervals left to optimize.
# Proportion of top-k intervals selected in worst case:
# Optimal: 0.647
# Optimal w/ Monotonic: 0.647
# Swiss: 0.62
# Top-k: 0.588

# %% [markdown]
# ### Half-Width Intervals

# %%
# half the width of the intervals 
half_intervals = [(x[i] - (x[i]-l)/2, x[i] + (h - x[i]) / 2) for i, (l,h) in enumerate(intervals)]
pruned, top, bottom = prune_instance(half_intervals, k)
pruned_intervals = [half_intervals[i] for i in pruned]
print("Accept {} intervals".format(len(top)))
print("Reject {} intervals".format(len(bottom)))
print("Remaining {} intervals".format(len(pruned)))
n_partitions = len(partition_intervals(intervals))
n_partitions_pruned = len(partition_intervals(pruned_intervals))
print("Number of partitions: {}".format(n_partitions))
print("Number of partitions pruned: {}".format(n_partitions_pruned))
# plot pruned intervals
plot_intervals(pruned_intervals)
plt.show()
# Out:
# Accept 100 intervals
# Reject 241 intervals
# Remaining 12 intervals
# Number of partitions: 2
# Number of partitions pruned: 1

# %%
v, p = solve_instance_unordered(half_intervals, k, k)
p_swiss = swiss_nsf(half_intervals, x, k)
# Out:
# Solving instance with n=353, k=106.
# Pruned 341 intervals. Solving with n=12, k=6.
# Solving with 30 constraints.
# Solved with optimal value: 3.499999999956701 out of 6.
# Finished post-processing solution.

# %%
vseq, pseq = solve_sequence(half_intervals, k, postprocess=True, lex_order_p=0, verbose=True, check_monotonicity=True, return_seq=True)
# Out:
# Solving instance with n=353, k=1.
# Pruned 348 intervals. Solving with n=5, k=1.
# Solving with 11 constraints.
# Solved with optimal value: 0.19999999979007665 out of 1.
# Finished post-processing solution.
# Solving instance with n=353, k=2.
# Pruned 347 intervals. Solving with n=6, k=2.
# Solving with 20 constraints.
# Solved with optimal value: 0.6666666666690205 out of 2.
# Finished post-processing solution.
# Solving instance with n=353, k=3.
# Pruned 346 intervals. Solving with n=7, k=3.
# Solving with 24 constraints.
# Solved with optimal value: 1.4999999999891127 out of 3.
# Finished post-processing solution.
# Solving instance with n=353, k=4.
# Pruned 346 intervals. Solving with n=7, k=4.
# Solving with 25 constraints.
# Solved with optimal value: 2.4999999999742517 out of 4.
# Finished post-processing solution.
# Solving instance with n=353, k=5.
# Pruned 347 intervals. Solving with n=6, k=4.
# Solving with 22 constraints.
# Solved with optimal value: 2.6666666666657526 out of 4.
# Finished post-processing solution.
# Solving instance with n=353, k=6.
# Pruned 348 intervals. Solving with n=5, k=4.
# Solving with 19 constraints.
# Solved with optimal value: 3.2000000000010957 out of 4.
# Finished post-processing solution.
# Solving instance with n=353, k=7.
# Pruned 353 intervals. Solving with n=0, k=0.
# Solving instance with n=353, k=8.
# Pruned 341 intervals. Solving with n=12, k=1.
# Solving with 37 constraints.
# Solved with optimal value: 0.08333333329454631 out of 1.
# Finished post-processing solution.
# Solving instance with n=353, k=9.
# Pruned 341 intervals. Solving with n=12, k=2.
# Solving with 38 constraints.
# Solved with optimal value: 0.3333333333442187 out of 2.
# Finished post-processing solution.
# Solving instance with n=353, k=10.
# Pruned 341 intervals. Solving with n=12, k=3.
# Solving with 39 constraints.
# Solved with optimal value: 0.7500000000575247 out of 3.
# Finished post-processing solution.
# Solving instance with n=353, k=11.
# Pruned 341 intervals. Solving with n=12, k=4.
# Solving with 40 constraints.
# Solved with optimal value: 1.3333333335090343 out of 4.
# Finished post-processing solution.
# Solving instance with n=353, k=12.
# Pruned 341 intervals. Solving with n=12, k=5.
# Solving with 41 constraints.
# Solved with optimal value: 2.0833333334611788 out of 5.
# Finished post-processing solution.
# Solving instance with n=353, k=13.
# Pruned 341 intervals. Solving with n=12, k=6.
# Solving with 42 constraints.
# Solved with optimal value: 3.00000000001596 out of 6.
# Finished post-processing solution.
# Solving instance with n=353, k=14.
# Pruned 341 intervals. Solving with n=12, k=7.
# Solving with 43 constraints.
# Solved with optimal value: 4.083333333372169 out of 7.
# Finished post-processing solution.
# Solving instance with n=353, k=15.
# Pruned 341 intervals. Solving with n=12, k=8.
# Solving with 44 constraints.
# Solved with optimal value: 5.333333333291459 out of 8.
# Finished post-processing solution.
# Solving instance with n=353, k=16.
# Pruned 341 intervals. Solving with n=12, k=9.
# Solving with 45 constraints.
# Solved with optimal value: 6.7499999999559455 out of 9.
# Finished post-processing solution.
# Solving instance with n=353, k=17.
# Pruned 341 intervals. Solving with n=12, k=10.
# Solving with 46 constraints.
# Solved with optimal value: 8.333333333286218 out of 10.
# Finished post-processing solution.
# Solving instance with n=353, k=18.
# Pruned 341 intervals. Solving with n=12, k=11.
# Solving with 47 constraints.
# Solved with optimal value: 10.083333333010797 out of 11.
# Finished post-processing solution.
# Solving instance with n=353, k=19.
# Pruned 353 intervals. Solving with n=0, k=0.
# Solving instance with n=353, k=20.
# Pruned 349 intervals. Solving with n=4, k=1.
# Solving with 13 constraints.
# Solved with optimal value: 0.24999999984794247 out of 1.
# Finished post-processing solution.
# Solving instance with n=353, k=21.
# Pruned 349 intervals. Solving with n=4, k=2.
# Solving with 14 constraints.
# Solved with optimal value: 1.0000000000375795 out of 2.
# Finished post-processing solution.
# Solving instance with n=353, k=22.
# Pruned 349 intervals. Solving with n=4, k=3.
# Solving with 15 constraints.
# Solved with optimal value: 2.2499999998392335 out of 3.
# Finished post-processing solution.
# Solving instance with n=353, k=23.
# Pruned 348 intervals. Solving with n=5, k=1.
# Solving with 16 constraints.
# Solved with optimal value: 0.06250000005835092 out of 1.
# Finished post-processing solution.
# Solving instance with n=353, k=24.
# Pruned 342 intervals. Solving with n=11, k=2.
# Solving with 35 constraints.
# Solved with optimal value: 0.6250000000343435 out of 2.
# Finished post-processing solution.
# Solving instance with n=353, k=25.
# Pruned 342 intervals. Solving with n=11, k=3.
# Solving with 36 constraints.
# Solved with optimal value: 1.1538461538919669 out of 3.
# Finished post-processing solution.
# Solving instance with n=353, k=26.
# Pruned 342 intervals. Solving with n=11, k=4.
# Solving with 37 constraints.
# Solved with optimal value: 1.666666666695034 out of 4.
# Finished post-processing solution.
# Solving instance with n=353, k=27.
# Pruned 343 intervals. Solving with n=10, k=4.
# Solving with 34 constraints.
# Solved with optimal value: 1.5555555555474385 out of 4.
# Finished post-processing solution.
# Solving instance with n=353, k=28.
# Pruned 342 intervals. Solving with n=11, k=5.
# Solving with 38 constraints.
# Solved with optimal value: 2.2727272727388437 out of 5.
# Finished post-processing solution.
# Solving instance with n=353, k=29.
# Pruned 342 intervals. Solving with n=11, k=6.
# Solving with 39 constraints.
# Solved with optimal value: 3.2727272727228214 out of 6.
# Finished post-processing solution.
# Solving instance with n=353, k=30.
# Pruned 341 intervals. Solving with n=12, k=7.
# Solving with 43 constraints.
# Solved with optimal value: 4.516589635215728 out of 7.
# Finished post-processing solution.
# Solving instance with n=353, k=31.
# Pruned 341 intervals. Solving with n=12, k=8.
# Solving with 44 constraints.
# Solved with optimal value: 5.516589635265129 out of 8.
# Finished post-processing solution.
# Solving instance with n=353, k=32.
# Pruned 340 intervals. Solving with n=13, k=9.
# Solving with 48 constraints.
# Solved with optimal value: 7.124999999976291 out of 9.
# Finished post-processing solution.
# Solving instance with n=353, k=33.
# Pruned 342 intervals. Solving with n=11, k=6.
# Solving with 39 constraints.
# Solved with optimal value: 4.125000000081593 out of 6.
# Finished post-processing solution.
# Solving instance with n=353, k=34.
# Pruned 339 intervals. Solving with n=14, k=5.
# Solving with 47 constraints.
# Solved with optimal value: 3.1875000000102975 out of 5.
# Finished post-processing solution.
# Solving instance with n=353, k=35.
# Pruned 337 intervals. Solving with n=16, k=4.
# Solving with 52 constraints.
# Solved with optimal value: 1.9890107150178034 out of 4.
# Finished post-processing solution.
# Solving instance with n=353, k=36.
# Pruned 338 intervals. Solving with n=15, k=4.
# Solving with 49 constraints.
# Solved with optimal value: 1.5156250000091456 out of 4.
# Finished post-processing solution.
# Solving instance with n=353, k=37.
# Pruned 336 intervals. Solving with n=17, k=5.
# Solving with 56 constraints.
# Solved with optimal value: 2.0884669992927956 out of 5.
# Finished post-processing solution.
# Solving instance with n=353, k=38.
# Pruned 332 intervals. Solving with n=21, k=5.
# Solving with 68 constraints.
# Solved with optimal value: 1.7048438627247409 out of 5.
# Finished post-processing solution.
# Solving instance with n=353, k=39.
# Pruned 332 intervals. Solving with n=21, k=6.
# Solving with 69 constraints.
# Solved with optimal value: 2.417910447760525 out of 6.
# Finished post-processing solution.
# Solving instance with n=353, k=40.
# Pruned 332 intervals. Solving with n=21, k=7.
# Solving with 70 constraints.
# Solved with optimal value: 3.1666666666189345 out of 7.
# Finished post-processing solution.
# Solving instance with n=353, k=41.
# Pruned 330 intervals. Solving with n=23, k=8.
# Solving with 77 constraints.
# Solved with optimal value: 3.8749999999840474 out of 8.
# Finished post-processing solution.
# Solving instance with n=353, k=42.
# Pruned 330 intervals. Solving with n=23, k=9.
# Solving with 78 constraints.
# Solved with optimal value: 4.471698113209737 out of 9.
# Finished post-processing solution.
# Solving instance with n=353, k=43.
# Pruned 326 intervals. Solving with n=27, k=9.
# Solving with 90 constraints.
# Solved with optimal value: 4.1707317073130845 out of 9.
# Finished post-processing solution.
# Solving instance with n=353, k=44.
# Pruned 326 intervals. Solving with n=27, k=10.
# Solving with 91 constraints.
# Solved with optimal value: 5.0000000000006075 out of 10.
# Finished post-processing solution.
# Solving instance with n=353, k=45.
# Pruned 326 intervals. Solving with n=27, k=11.
# Solving with 92 constraints.
# Solved with optimal value: 6.0376136408707435 out of 11.
# Finished post-processing solution.
# Solving instance with n=353, k=46.
# Pruned 326 intervals. Solving with n=27, k=12.
# Solving with 93 constraints.
# Solved with optimal value: 6.774492197035272 out of 12.
# Finished post-processing solution.
# Solving instance with n=353, k=47.
# Pruned 328 intervals. Solving with n=25, k=11.
# Solving with 86 constraints.
# Solved with optimal value: 5.513860621525822 out of 11.
# Finished post-processing solution.
# Solving instance with n=353, k=48.
# Pruned 326 intervals. Solving with n=27, k=12.
# Solving with 93 constraints.
# Solved with optimal value: 6.235946202328119 out of 12.
# Finished post-processing solution.
# Solving instance with n=353, k=49.
# Pruned 327 intervals. Solving with n=26, k=12.
# Solving with 90 constraints.
# Solved with optimal value: 5.9999999999987965 out of 12.
# Finished post-processing solution.
# Solving instance with n=353, k=50.
# Pruned 327 intervals. Solving with n=26, k=13.
# Solving with 91 constraints.
# Solved with optimal value: 7.258295541945369 out of 13.
# Finished post-processing solution.
# Solving instance with n=353, k=51.
# Pruned 324 intervals. Solving with n=29, k=14.
# Solving with 101 constraints.
# Solved with optimal value: 8.527375019945334 out of 14.
# Finished post-processing solution.
# Solving instance with n=353, k=52.
# Pruned 323 intervals. Solving with n=30, k=15.
# Solving with 105 constraints.
# Solved with optimal value: 9.574906753803457 out of 15.
# Finished post-processing solution.
# Solving instance with n=353, k=53.
# Pruned 320 intervals. Solving with n=33, k=16.
# Solving with 115 constraints.
# Solved with optimal value: 10.499999999986498 out of 16.
# Finished post-processing solution.
# Solving instance with n=353, k=54.
# Pruned 319 intervals. Solving with n=34, k=14.
# Solving with 116 constraints.
# Solved with optimal value: 8.398538839747978 out of 14.
# Finished post-processing solution.
# Solving instance with n=353, k=55.
# Pruned 314 intervals. Solving with n=39, k=15.
# Solving with 132 constraints.
# Solved with optimal value: 9.398538839880679 out of 15.
# Finished post-processing solution.
# Solving instance with n=353, k=56.
# Pruned 314 intervals. Solving with n=39, k=14.
# Solving with 131 constraints.
# Solved with optimal value: 8.742934773849317 out of 14.
# Finished post-processing solution.
# Solving instance with n=353, k=57.
# Pruned 313 intervals. Solving with n=40, k=15.
# Solving with 135 constraints.
# Solved with optimal value: 9.712866304160563 out of 15.
# Finished post-processing solution.
# Solving instance with n=353, k=58.
# Pruned 313 intervals. Solving with n=40, k=16.
# Solving with 136 constraints.
# Solved with optimal value: 10.461538461514388 out of 16.
# Finished post-processing solution.
# Solving instance with n=353, k=59.
# Pruned 313 intervals. Solving with n=40, k=17.
# Solving with 137 constraints.
# Solved with optimal value: 11.231891236396747 out of 17.
# Finished post-processing solution.
# Solving instance with n=353, k=60.
# Pruned 311 intervals. Solving with n=42, k=18.
# Solving with 144 constraints.
# Solved with optimal value: 11.902862984963177 out of 18.
# Finished post-processing solution.
# Solving instance with n=353, k=61.
# Pruned 316 intervals. Solving with n=37, k=14.
# Solving with 125 constraints.
# Solved with optimal value: 7.569047777673603 out of 14.
# Finished post-processing solution.
# Solving instance with n=353, k=62.
# Pruned 315 intervals. Solving with n=38, k=15.
# Solving with 129 constraints.
# Solved with optimal value: 8.303800789509063 out of 15.
# Finished post-processing solution.
# Solving instance with n=353, k=63.
# Pruned 318 intervals. Solving with n=35, k=13.
# Solving with 118 constraints.
# Solved with optimal value: 6.059614598086355 out of 13.
# Finished post-processing solution.
# Solving instance with n=353, k=64.
# Pruned 317 intervals. Solving with n=36, k=14.
# Solving with 122 constraints.
# Solved with optimal value: 6.833969917335419 out of 14.
# Finished post-processing solution.
# Solving instance with n=353, k=65.
# Pruned 317 intervals. Solving with n=36, k=15.
# Solving with 123 constraints.
# Solved with optimal value: 7.696379031325598 out of 15.
# Finished post-processing solution.
# Solving instance with n=353, k=66.
# Pruned 318 intervals. Solving with n=35, k=15.
# Solving with 120 constraints.
# Solved with optimal value: 7.533025757666592 out of 15.
# Finished post-processing solution.
# Solving instance with n=353, k=67.
# Pruned 319 intervals. Solving with n=34, k=15.
# Solving with 117 constraints.
# Solved with optimal value: 7.376518218629284 out of 15.
# Finished post-processing solution.
# Solving instance with n=353, k=68.
# Pruned 319 intervals. Solving with n=34, k=16.
# Solving with 118 constraints.
# Solved with optimal value: 8.2874999999944 out of 16.
# Finished post-processing solution.
# Solving instance with n=353, k=69.
# Pruned 317 intervals. Solving with n=36, k=17.
# Solving with 125 constraints.
# Solved with optimal value: 9.127289961166285 out of 17.
# Finished post-processing solution.
# Solving instance with n=353, k=70.
# Pruned 318 intervals. Solving with n=35, k=17.
# Solving with 122 constraints.
# Solved with optimal value: 9.000000000029523 out of 17.
# Finished post-processing solution.
# Solving instance with n=353, k=71.
# Pruned 318 intervals. Solving with n=35, k=18.
# Solving with 123 constraints.
# Solved with optimal value: 10.127494097394644 out of 18.
# Finished post-processing solution.
# Solving instance with n=353, k=72.
# Pruned 318 intervals. Solving with n=35, k=19.
# Solving with 124 constraints.
# Solved with optimal value: 11.3225806451564 out of 19.
# Finished post-processing solution.
# Solving instance with n=353, k=73.
# Pruned 318 intervals. Solving with n=35, k=20.
# Solving with 125 constraints.
# Solved with optimal value: 12.41592920353694 out of 20.
# Finished post-processing solution.
# Solving instance with n=353, k=74.
# Pruned 319 intervals. Solving with n=34, k=20.
# Solving with 122 constraints.
# Solved with optimal value: 12.415929204444593 out of 20.
# Finished post-processing solution.
# Solving instance with n=353, k=75.
# Pruned 318 intervals. Solving with n=35, k=21.
# Solving with 126 constraints.
# Solved with optimal value: 13.637168142012795 out of 21.
# Finished post-processing solution.
# Solving instance with n=353, k=76.
# Pruned 318 intervals. Solving with n=35, k=22.
# Solving with 127 constraints.
# Solved with optimal value: 15.043478260807078 out of 22.
# Finished post-processing solution.
# Solving instance with n=353, k=77.
# Pruned 318 intervals. Solving with n=35, k=23.
# Solving with 128 constraints.
# Solved with optimal value: 16.35570469779321 out of 23.
# Finished post-processing solution.
# Solving instance with n=353, k=78.
# Pruned 318 intervals. Solving with n=35, k=24.
# Solving with 129 constraints.
# Solved with optimal value: 17.52796420598099 out of 24.
# Finished post-processing solution.
# Solving instance with n=353, k=79.
# Pruned 319 intervals. Solving with n=34, k=24.
# Solving with 126 constraints.
# Solved with optimal value: 17.905191873517747 out of 24.
# Finished post-processing solution.
# Solving instance with n=353, k=80.
# Pruned 318 intervals. Solving with n=35, k=25.
# Solving with 130 constraints.
# Solved with optimal value: 19.298136645908546 out of 25.
# Finished post-processing solution.
# Solving instance with n=353, k=81.
# Pruned 319 intervals. Solving with n=34, k=25.
# Solving with 127 constraints.
# Solved with optimal value: 19.666666666585147 out of 25.
# Finished post-processing solution.
# Solving instance with n=353, k=82.
# Pruned 321 intervals. Solving with n=32, k=23.
# Solving with 119 constraints.
# Solved with optimal value: 18.00000000002491 out of 23.
# Finished post-processing solution.
# Solving instance with n=353, k=83.
# Pruned 321 intervals. Solving with n=32, k=24.
# Solving with 120 constraints.
# Solved with optimal value: 19.333333333481747 out of 24.
# Finished post-processing solution.
# Solving instance with n=353, k=84.
# Pruned 321 intervals. Solving with n=32, k=23.
# Solving with 119 constraints.
# Solved with optimal value: 18.63804278687988 out of 23.
# Finished post-processing solution.
# Solving instance with n=353, k=85.
# Pruned 323 intervals. Solving with n=30, k=22.
# Solving with 112 constraints.
# Solved with optimal value: 18.105444771976266 out of 22.
# Finished post-processing solution.
# Solving instance with n=353, k=86.
# Pruned 325 intervals. Solving with n=28, k=18.
# Solving with 102 constraints.
# Solved with optimal value: 14.499999999827043 out of 18.
# Finished post-processing solution.
# Solving instance with n=353, k=87.
# Pruned 325 intervals. Solving with n=28, k=19.
# Solving with 103 constraints.
# Solved with optimal value: 15.527871054707632 out of 19.
# Finished post-processing solution.
# Solving instance with n=353, k=88.
# Pruned 331 intervals. Solving with n=22, k=14.
# Solving with 80 constraints.
# Solved with optimal value: 10.622619938238518 out of 14.
# Finished post-processing solution.
# Solving instance with n=353, k=89.
# Pruned 336 intervals. Solving with n=17, k=10.
# Solving with 61 constraints.
# Solved with optimal value: 6.579242341245694 out of 10.
# Finished post-processing solution.
# Solving instance with n=353, k=90.
# Pruned 333 intervals. Solving with n=20, k=9.
# Solving with 69 constraints.
# Solved with optimal value: 5.686086394328855 out of 9.
# Finished post-processing solution.
# Solving instance with n=353, k=91.
# Pruned 335 intervals. Solving with n=18, k=8.
# Solving with 62 constraints.
# Solved with optimal value: 4.740141086315841 out of 8.
# Finished post-processing solution.
# Solving instance with n=353, k=92.
# Pruned 334 intervals. Solving with n=19, k=9.
# Solving with 66 constraints.
# Solved with optimal value: 5.500000000009049 out of 9.
# Finished post-processing solution.
# Solving instance with n=353, k=93.
# Pruned 336 intervals. Solving with n=17, k=8.
# Solving with 59 constraints.
# Solved with optimal value: 4.400000000005287 out of 8.
# Finished post-processing solution.
# Solving instance with n=353, k=94.
# Pruned 335 intervals. Solving with n=18, k=9.
# Solving with 63 constraints.
# Solved with optimal value: 5.500000000000954 out of 9.
# Finished post-processing solution.
# Solving instance with n=353, k=95.
# Pruned 335 intervals. Solving with n=18, k=10.
# Solving with 64 constraints.
# Solved with optimal value: 6.540980970528286 out of 10.
# Finished post-processing solution.
# Solving instance with n=353, k=96.
# Pruned 338 intervals. Solving with n=15, k=7.
# Solving with 52 constraints.
# Solved with optimal value: 3.5000000000270255 out of 7.
# Finished post-processing solution.
# Solving instance with n=353, k=97.
# Pruned 337 intervals. Solving with n=16, k=8.
# Solving with 56 constraints.
# Solved with optimal value: 4.571428571412046 out of 8.
# Finished post-processing solution.
# Solving instance with n=353, k=98.
# Pruned 337 intervals. Solving with n=16, k=9.
# Solving with 57 constraints.
# Solved with optimal value: 5.571428571715018 out of 9.
# Finished post-processing solution.
# Solving instance with n=353, k=99.
# Pruned 337 intervals. Solving with n=16, k=10.
# Solving with 58 constraints.
# Solved with optimal value: 6.857142857153522 out of 10.
# Finished post-processing solution.
# Solving instance with n=353, k=100.
# Pruned 337 intervals. Solving with n=16, k=11.
# Solving with 59 constraints.
# Solved with optimal value: 8.083333333465339 out of 11.
# Finished post-processing solution.
# Solving instance with n=353, k=101.
# Pruned 336 intervals. Solving with n=17, k=10.
# Solving with 61 constraints.
# Solved with optimal value: 7.454545454537822 out of 10.
# Finished post-processing solution.
# Solving instance with n=353, k=102.
# Pruned 336 intervals. Solving with n=17, k=9.
# Solving with 60 constraints.
# Solved with optimal value: 6.428571428568908 out of 9.
# Finished post-processing solution.
# Solving instance with n=353, k=103.
# Pruned 338 intervals. Solving with n=15, k=8.
# Solving with 53 constraints.
# Solved with optimal value: 5.428571428598569 out of 8.
# Finished post-processing solution.
# Solving instance with n=353, k=104.
# Pruned 339 intervals. Solving with n=14, k=8.
# Solving with 50 constraints.
# Solved with optimal value: 5.315965241164569 out of 8.
# Finished post-processing solution.
# Solving instance with n=353, k=105.
# Pruned 343 intervals. Solving with n=10, k=5.
# Solving with 35 constraints.
# Solved with optimal value: 2.309158331447946 out of 5.
# Finished post-processing solution.
# Solving instance with n=353, k=106.
# Pruned 341 intervals. Solving with n=12, k=6.
# Solving with 42 constraints.
# Solved with optimal value: 3.499999999993356 out of 6.
# Finished post-processing solution.

# %%
verify_posthoc_validity(half_intervals, p)
# Out:
# True

# %%
valid = [verify_posthoc_validity(half_intervals, p) for p in pseq]
1. * sum(valid) / len(valid)
# Out:
# 1.0

# %%
n_top = len(top)
pct_swiss = np.round((evaluate_p([(l/2., u/2.) for (l,u) in half_intervals], p_swiss, k) - n_top) / (k-n_top), 3)
pct_opt = np.round((evaluate_p([(l/2., u/2.) for (l,u) in half_intervals], p, k) - n_top) / (k-n_top), 3)
pct_opt_monotonic = np.round((evaluate_p([(l/2., u/2.) for (l,u) in half_intervals], pseq[-1], k) - n_top) / (k-n_top), 3)
pct_topk = np.round((evaluate_p([(l/2., u/2.) for (l,u) in half_intervals], [1]*k+[0]*(n-k), k) - n_top) / (k-n_top), 3)

print(f"Always select {n_top}, {k-n_top} intervals left to optimize.")
print("Proportion of top-k intervals selected in worst case:")
print(f"Optimal: {pct_opt}")
print(f"Optimal w/ Monotonic: {pct_opt_monotonic}")
print(f"Swiss: {pct_swiss}")
print(f"Top-k: {pct_topk}")
# Out:
# Always select 100, 6 intervals left to optimize.
# Proportion of top-k intervals selected in worst case:
# Optimal: 0.583
# Optimal w/ Monotonic: 0.583
# Swiss: 0.524
# Top-k: 0.333

# %% [markdown]
# ### 90% CIs

# %%
# Use 90% CIs instead of 50% CIs
pruned, top, bottom = prune_instance(intervals90, k)
pruned_intervals = [intervals90[i] for i in pruned]
print("Accept {} intervals".format(len(top)))
print("Reject {} intervals".format(len(bottom)))
print("Remaining {} intervals".format(len(pruned)))
n_partitions = len(partition_intervals(intervals))
n_partitions_pruned = len(partition_intervals(pruned_intervals))
print("Number of partitions: {}".format(n_partitions))
print("Number of partitions pruned: {}".format(n_partitions_pruned))
# plot pruned intervals
plot_intervals(pruned_intervals)
plt.show()
# Out:
# Accept 38 intervals
# Reject 183 intervals
# Remaining 132 intervals
# Number of partitions: 2
# Number of partitions pruned: 1

# %%
v, p = solve_instance_unordered(intervals90, k, k)
p_swiss = swiss_nsf(intervals90, x, k)
# Out:
# Solving instance with n=353, k=106.
# Pruned 221 intervals. Solving with n=132, k=68.
# Solving with 332 constraints.
# Solved with optimal value: 49.014124290973164 out of 68.
# Finished post-processing solution.

# %%
vseq, pseq = solve_sequence(intervals90, k, postprocess=True, lex_order_p=0, verbose=True, check_monotonicity=True, return_seq=True)
# Out:
# Solving instance with n=353, k=1.
# Pruned 334 intervals. Solving with n=19, k=1.
# Solving with 39 constraints.
# Solved with optimal value: 0.05263157876865677 out of 1.
# Finished post-processing solution.
# Solving instance with n=353, k=2.
# Pruned 331 intervals. Solving with n=22, k=2.
# Solving with 68 constraints.
# Solved with optimal value: 0.2000000000034756 out of 2.
# Finished post-processing solution.
# Solving instance with n=353, k=3.
# Pruned 331 intervals. Solving with n=22, k=3.
# Solving with 69 constraints.
# Solved with optimal value: 0.4285714286383294 out of 3.
# Finished post-processing solution.
# Solving instance with n=353, k=4.
# Pruned 331 intervals. Solving with n=22, k=4.
# Solving with 70 constraints.
# Solved with optimal value: 0.7272727273421414 out of 4.
# Finished post-processing solution.
# Solving instance with n=353, k=5.
# Pruned 330 intervals. Solving with n=23, k=5.
# Solving with 74 constraints.
# Solved with optimal value: 1.1363636363880854 out of 5.
# Finished post-processing solution.
# Solving instance with n=353, k=6.
# Pruned 328 intervals. Solving with n=25, k=6.
# Solving with 81 constraints.
# Solved with optimal value: 1.6363636364270913 out of 6.
# Finished post-processing solution.
# Solving instance with n=353, k=7.
# Pruned 321 intervals. Solving with n=32, k=7.
# Solving with 103 constraints.
# Solved with optimal value: 2.2000000000169484 out of 7.
# Finished post-processing solution.
# Solving instance with n=353, k=8.
# Pruned 314 intervals. Solving with n=39, k=8.
# Solving with 125 constraints.
# Solved with optimal value: 2.7692307692316365 out of 8.
# Finished post-processing solution.
# Solving instance with n=353, k=9.
# Pruned 311 intervals. Solving with n=42, k=9.
# Solving with 135 constraints.
# Solved with optimal value: 3.389610389630768 out of 9.
# Finished post-processing solution.
# Solving instance with n=353, k=10.
# Pruned 311 intervals. Solving with n=42, k=10.
# Solving with 136 constraints.
# Solved with optimal value: 4.074074074088354 out of 10.
# Finished post-processing solution.
# Solving instance with n=353, k=11.
# Pruned 311 intervals. Solving with n=42, k=11.
# Solving with 137 constraints.
# Solved with optimal value: 4.714285714254628 out of 11.
# Finished post-processing solution.
# Solving instance with n=353, k=12.
# Pruned 311 intervals. Solving with n=42, k=12.
# Solving with 138 constraints.
# Solved with optimal value: 5.37931034482157 out of 12.
# Finished post-processing solution.
# Solving instance with n=353, k=13.
# Pruned 309 intervals. Solving with n=44, k=13.
# Solving with 145 constraints.
# Solved with optimal value: 6.0562248995784715 out of 13.
# Finished post-processing solution.
# Solving instance with n=353, k=14.
# Pruned 309 intervals. Solving with n=44, k=14.
# Solving with 146 constraints.
# Solved with optimal value: 6.6363917207292875 out of 14.
# Finished post-processing solution.
# Solving instance with n=353, k=15.
# Pruned 309 intervals. Solving with n=44, k=15.
# Solving with 147 constraints.
# Solved with optimal value: 7.178045515391628 out of 15.
# Finished post-processing solution.
# Solving instance with n=353, k=16.
# Pruned 309 intervals. Solving with n=44, k=16.
# Solving with 148 constraints.
# Solved with optimal value: 7.785714285775805 out of 16.
# Finished post-processing solution.
# Solving instance with n=353, k=17.
# Pruned 303 intervals. Solving with n=50, k=17.
# Solving with 167 constraints.
# Solved with optimal value: 8.448240198632268 out of 17.
# Finished post-processing solution.
# Solving instance with n=353, k=18.
# Pruned 299 intervals. Solving with n=54, k=18.
# Solving with 180 constraints.
# Solved with optimal value: 9.181753500152658 out of 18.
# Finished post-processing solution.
# Solving instance with n=353, k=19.
# Pruned 300 intervals. Solving with n=53, k=18.
# Solving with 177 constraints.
# Solved with optimal value: 9.040424008866774 out of 18.
# Finished post-processing solution.
# Solving instance with n=353, k=20.
# Pruned 282 intervals. Solving with n=71, k=19.
# Solving with 232 constraints.
# Solved with optimal value: 9.963676373292076 out of 19.
# Finished post-processing solution.
# Solving instance with n=353, k=21.
# Pruned 276 intervals. Solving with n=77, k=20.
# Solving with 251 constraints.
# Solved with optimal value: 10.841295797517775 out of 20.
# Finished post-processing solution.
# Solving instance with n=353, k=22.
# Pruned 279 intervals. Solving with n=74, k=18.
# Solving with 240 constraints.
# Solved with optimal value: 8.521555413612553 out of 18.
# Finished post-processing solution.
# Solving instance with n=353, k=23.
# Pruned 275 intervals. Solving with n=78, k=18.
# Solving with 252 constraints.
# Solved with optimal value: 8.206088702103678 out of 18.
# Finished post-processing solution.
# Solving instance with n=353, k=24.
# Pruned 269 intervals. Solving with n=84, k=19.
# Solving with 271 constraints.
# Solved with optimal value: 8.873288406742681 out of 19.
# Finished post-processing solution.
# Solving instance with n=353, k=25.
# Pruned 270 intervals. Solving with n=83, k=19.
# Solving with 268 constraints.
# Solved with optimal value: 8.6328082322212 out of 19.
# Finished post-processing solution.
# Solving instance with n=353, k=26.
# Pruned 269 intervals. Solving with n=84, k=20.
# Solving with 272 constraints.
# Solved with optimal value: 9.424104230975699 out of 20.
# Finished post-processing solution.
# Solving instance with n=353, k=27.
# Pruned 269 intervals. Solving with n=84, k=21.
# Solving with 273 constraints.
# Solved with optimal value: 10.120489998322727 out of 21.
# Finished post-processing solution.
# Solving instance with n=353, k=28.
# Pruned 268 intervals. Solving with n=85, k=22.
# Solving with 277 constraints.
# Solved with optimal value: 10.829729255581523 out of 22.
# Finished post-processing solution.
# Solving instance with n=353, k=29.
# Pruned 268 intervals. Solving with n=85, k=23.
# Solving with 278 constraints.
# Solved with optimal value: 11.541666666655583 out of 23.
# Finished post-processing solution.
# Solving instance with n=353, k=30.
# Pruned 265 intervals. Solving with n=88, k=24.
# Solving with 288 constraints.
# Solved with optimal value: 12.307291666119534 out of 24.
# Finished post-processing solution.
# Solving instance with n=353, k=31.
# Pruned 265 intervals. Solving with n=88, k=25.
# Solving with 289 constraints.
# Solved with optimal value: 12.976190475998395 out of 25.
# Finished post-processing solution.
# Solving instance with n=353, k=32.
# Pruned 264 intervals. Solving with n=89, k=25.
# Solving with 292 constraints.
# Solved with optimal value: 12.594086021234121 out of 25.
# Finished post-processing solution.
# Solving instance with n=353, k=33.
# Pruned 263 intervals. Solving with n=90, k=26.
# Solving with 296 constraints.
# Solved with optimal value: 13.211538461322716 out of 26.
# Finished post-processing solution.
# Solving instance with n=353, k=34.
# Pruned 259 intervals. Solving with n=94, k=27.
# Solving with 309 constraints.
# Solved with optimal value: 13.769675078349069 out of 27.
# Finished post-processing solution.
# Solving instance with n=353, k=35.
# Pruned 259 intervals. Solving with n=94, k=28.
# Solving with 310 constraints.
# Solved with optimal value: 14.325447624149048 out of 28.
# Finished post-processing solution.
# Solving instance with n=353, k=36.
# Pruned 257 intervals. Solving with n=96, k=29.
# Solving with 317 constraints.
# Solved with optimal value: 14.81589662501058 out of 29.
# Finished post-processing solution.
# Solving instance with n=353, k=37.
# Pruned 256 intervals. Solving with n=97, k=30.
# Solving with 321 constraints.
# Solved with optimal value: 15.290745801712752 out of 30.
# Finished post-processing solution.
# Solving instance with n=353, k=38.
# Pruned 255 intervals. Solving with n=98, k=31.
# Solving with 325 constraints.
# Solved with optimal value: 15.794008274503321 out of 31.
# Finished post-processing solution.
# Solving instance with n=353, k=39.
# Pruned 254 intervals. Solving with n=99, k=31.
# Solving with 328 constraints.
# Solved with optimal value: 15.332434591385924 out of 31.
# Finished post-processing solution.
# Solving instance with n=353, k=40.
# Pruned 254 intervals. Solving with n=99, k=32.
# Solving with 329 constraints.
# Solved with optimal value: 15.907059772599977 out of 32.
# Finished post-processing solution.
# Solving instance with n=353, k=41.
# Pruned 254 intervals. Solving with n=99, k=33.
# Solving with 330 constraints.
# Solved with optimal value: 16.572101834292813 out of 33.
# Finished post-processing solution.
# Solving instance with n=353, k=42.
# Pruned 258 intervals. Solving with n=95, k=30.
# Solving with 315 constraints.
# Solved with optimal value: 13.276359582373319 out of 30.
# Finished post-processing solution.
# Solving instance with n=353, k=43.
# Pruned 255 intervals. Solving with n=98, k=31.
# Solving with 325 constraints.
# Solved with optimal value: 14.019833016159787 out of 31.
# Finished post-processing solution.
# Solving instance with n=353, k=44.
# Pruned 259 intervals. Solving with n=94, k=28.
# Solving with 310 constraints.
# Solved with optimal value: 10.802522136820299 out of 28.
# Finished post-processing solution.
# Solving instance with n=353, k=45.
# Pruned 259 intervals. Solving with n=94, k=29.
# Solving with 311 constraints.
# Solved with optimal value: 11.569244050492443 out of 29.
# Finished post-processing solution.
# Solving instance with n=353, k=46.
# Pruned 259 intervals. Solving with n=94, k=30.
# Solving with 312 constraints.
# Solved with optimal value: 12.28646719315534 out of 30.
# Finished post-processing solution.
# Solving instance with n=353, k=47.
# Pruned 259 intervals. Solving with n=94, k=31.
# Solving with 313 constraints.
# Solved with optimal value: 12.941759269181311 out of 31.
# Finished post-processing solution.
# Solving instance with n=353, k=48.
# Pruned 258 intervals. Solving with n=95, k=32.
# Solving with 317 constraints.
# Solved with optimal value: 13.614865115170813 out of 32.
# Finished post-processing solution.
# Solving instance with n=353, k=49.
# Pruned 258 intervals. Solving with n=95, k=33.
# Solving with 318 constraints.
# Solved with optimal value: 14.310069345692197 out of 33.
# Finished post-processing solution.
# Solving instance with n=353, k=50.
# Pruned 259 intervals. Solving with n=94, k=33.
# Solving with 315 constraints.
# Solved with optimal value: 14.042138186612881 out of 33.
# Finished post-processing solution.
# Solving instance with n=353, k=51.
# Pruned 259 intervals. Solving with n=94, k=34.
# Solving with 316 constraints.
# Solved with optimal value: 14.791655391886826 out of 34.
# Finished post-processing solution.
# Solving instance with n=353, k=52.
# Pruned 259 intervals. Solving with n=94, k=35.
# Solving with 317 constraints.
# Solved with optimal value: 15.55315346821881 out of 35.
# Finished post-processing solution.
# Solving instance with n=353, k=53.
# Pruned 259 intervals. Solving with n=94, k=36.
# Solving with 318 constraints.
# Solved with optimal value: 16.29851152151493 out of 36.
# Finished post-processing solution.
# Solving instance with n=353, k=54.
# Pruned 260 intervals. Solving with n=93, k=35.
# Solving with 314 constraints.
# Solved with optimal value: 15.062141590086798 out of 35.
# Finished post-processing solution.
# Solving instance with n=353, k=55.
# Pruned 256 intervals. Solving with n=97, k=36.
# Solving with 327 constraints.
# Solved with optimal value: 15.797565957067786 out of 36.
# Finished post-processing solution.
# Solving instance with n=353, k=56.
# Pruned 253 intervals. Solving with n=100, k=37.
# Solving with 337 constraints.
# Solved with optimal value: 16.532177045338887 out of 37.
# Finished post-processing solution.
# Solving instance with n=353, k=57.
# Pruned 253 intervals. Solving with n=100, k=38.
# Solving with 338 constraints.
# Solved with optimal value: 17.33313890992206 out of 38.
# Finished post-processing solution.
# Solving instance with n=353, k=58.
# Pruned 253 intervals. Solving with n=100, k=39.
# Solving with 339 constraints.
# Solved with optimal value: 18.15411039748225 out of 39.
# Finished post-processing solution.
# Solving instance with n=353, k=59.
# Pruned 250 intervals. Solving with n=103, k=40.
# Solving with 349 constraints.
# Solved with optimal value: 18.994332233694884 out of 40.
# Finished post-processing solution.
# Solving instance with n=353, k=60.
# Pruned 250 intervals. Solving with n=103, k=41.
# Solving with 350 constraints.
# Solved with optimal value: 19.85213307867528 out of 41.
# Finished post-processing solution.
# Solving instance with n=353, k=61.
# Pruned 250 intervals. Solving with n=103, k=42.
# Solving with 351 constraints.
# Solved with optimal value: 20.695725160291005 out of 42.
# Finished post-processing solution.
# Solving instance with n=353, k=62.
# Pruned 249 intervals. Solving with n=104, k=43.
# Solving with 355 constraints.
# Solved with optimal value: 21.515018442790307 out of 43.
# Finished post-processing solution.
# Solving instance with n=353, k=63.
# Pruned 249 intervals. Solving with n=104, k=44.
# Solving with 356 constraints.
# Solved with optimal value: 22.34831460680471 out of 44.
# Finished post-processing solution.
# Solving instance with n=353, k=64.
# Pruned 247 intervals. Solving with n=106, k=45.
# Solving with 363 constraints.
# Solved with optimal value: 23.280776143357773 out of 45.
# Finished post-processing solution.
# Solving instance with n=353, k=65.
# Pruned 247 intervals. Solving with n=106, k=46.
# Solving with 364 constraints.
# Solved with optimal value: 24.275862068912122 out of 46.
# Finished post-processing solution.
# Solving instance with n=353, k=66.
# Pruned 247 intervals. Solving with n=106, k=47.
# Solving with 365 constraints.
# Solved with optimal value: 25.252873562972866 out of 47.
# Finished post-processing solution.
# Solving instance with n=353, k=67.
# Pruned 247 intervals. Solving with n=106, k=48.
# Solving with 366 constraints.
# Solved with optimal value: 26.25287356301642 out of 48.
# Finished post-processing solution.
# Solving instance with n=353, k=68.
# Pruned 247 intervals. Solving with n=106, k=49.
# Solving with 367 constraints.
# Solved with optimal value: 27.216606830194095 out of 49.
# Finished post-processing solution.
# Solving instance with n=353, k=69.
# Pruned 247 intervals. Solving with n=106, k=50.
# Solving with 368 constraints.
# Solved with optimal value: 28.243243243251797 out of 50.
# Finished post-processing solution.
# Solving instance with n=353, k=70.
# Pruned 247 intervals. Solving with n=106, k=51.
# Solving with 369 constraints.
# Solved with optimal value: 29.34831460680048 out of 51.
# Finished post-processing solution.
# Solving instance with n=353, k=71.
# Pruned 243 intervals. Solving with n=110, k=52.
# Solving with 579 constraints.
# Solved with optimal value: 30.597785975844154 out of 52.
# Finished post-processing solution.
# Solving instance with n=353, k=72.
# Pruned 244 intervals. Solving with n=109, k=52.
# Solving with 379 constraints.
# Solved with optimal value: 30.55350553423807 out of 52.
# Finished post-processing solution.
# Solving instance with n=353, k=73.
# Pruned 244 intervals. Solving with n=109, k=53.
# Solving with 380 constraints.
# Solved with optimal value: 31.39483394816917 out of 53.
# Finished post-processing solution.
# Solving instance with n=353, k=74.
# Pruned 244 intervals. Solving with n=109, k=54.
# Solving with 381 constraints.
# Solved with optimal value: 32.308501479750234 out of 54.
# Finished post-processing solution.
# Solving instance with n=353, k=75.
# Pruned 244 intervals. Solving with n=109, k=55.
# Solving with 382 constraints.
# Solved with optimal value: 33.27289169166076 out of 55.
# Finished post-processing solution.
# Solving instance with n=353, k=76.
# Pruned 244 intervals. Solving with n=109, k=56.
# Solving with 383 constraints.
# Solved with optimal value: 34.17849500260186 out of 56.
# Finished post-processing solution.
# Solving instance with n=353, k=77.
# Pruned 244 intervals. Solving with n=109, k=57.
# Solving with 384 constraints.
# Solved with optimal value: 35.105999653364556 out of 57.
# Finished post-processing solution.
# Solving instance with n=353, k=78.
# Pruned 245 intervals. Solving with n=108, k=56.
# Solving with 380 constraints.
# Solved with optimal value: 34.08457703170506 out of 56.
# Finished post-processing solution.
# Solving instance with n=353, k=79.
# Pruned 245 intervals. Solving with n=108, k=57.
# Solving with 381 constraints.
# Solved with optimal value: 35.137752441086505 out of 57.
# Finished post-processing solution.
# Solving instance with n=353, k=80.
# Pruned 243 intervals. Solving with n=110, k=58.
# Solving with 388 constraints.
# Solved with optimal value: 36.17506325394245 out of 58.
# Finished post-processing solution.
# Solving instance with n=353, k=81.
# Pruned 243 intervals. Solving with n=110, k=59.
# Solving with 389 constraints.
# Solved with optimal value: 37.22622132166971 out of 59.
# Finished post-processing solution.
# Solving instance with n=353, k=82.
# Pruned 242 intervals. Solving with n=111, k=60.
# Solving with 566 constraints.
# Solved with optimal value: 38.192903142232055 out of 60.
# Finished post-processing solution.
# Solving instance with n=353, k=83.
# Pruned 243 intervals. Solving with n=110, k=60.
# Solving with 390 constraints.
# Solved with optimal value: 38.33864248666488 out of 60.
# Finished post-processing solution.
# Solving instance with n=353, k=84.
# Pruned 243 intervals. Solving with n=110, k=61.
# Solving with 391 constraints.
# Solved with optimal value: 39.511034318250076 out of 61.
# Finished post-processing solution.
# Solving instance with n=353, k=85.
# Pruned 242 intervals. Solving with n=111, k=62.
# Solving with 395 constraints.
# Solved with optimal value: 40.729291252440184 out of 62.
# Finished post-processing solution.
# Solving instance with n=353, k=86.
# Pruned 239 intervals. Solving with n=114, k=63.
# Solving with 405 constraints.
# Solved with optimal value: 41.99402122791854 out of 63.
# Finished post-processing solution.
# Solving instance with n=353, k=87.
# Pruned 239 intervals. Solving with n=114, k=64.
# Solving with 406 constraints.
# Solved with optimal value: 43.009138682533205 out of 64.
# Finished post-processing solution.
# Solving instance with n=353, k=88.
# Pruned 237 intervals. Solving with n=116, k=65.
# Solving with 413 constraints.
# Solved with optimal value: 44.00913868631857 out of 65.
# Finished post-processing solution.
# Solving instance with n=353, k=89.
# Pruned 238 intervals. Solving with n=115, k=64.
# Solving with 409 constraints.
# Solved with optimal value: 43.092054640125504 out of 64.
# Finished post-processing solution.
# Solving instance with n=353, k=90.
# Pruned 232 intervals. Solving with n=121, k=63.
# Solving with 426 constraints.
# Solved with optimal value: 42.36630905524925 out of 63.
# Finished post-processing solution.
# Solving instance with n=353, k=91.
# Pruned 234 intervals. Solving with n=119, k=62.
# Solving with 419 constraints.
# Solved with optimal value: 41.69792810269114 out of 62.
# Finished post-processing solution.
# Solving instance with n=353, k=92.
# Pruned 234 intervals. Solving with n=119, k=63.
# Solving with 420 constraints.
# Solved with optimal value: 43.02743261105032 out of 63.
# Finished post-processing solution.
# Solving instance with n=353, k=93.
# Pruned 234 intervals. Solving with n=119, k=64.
# Solving with 421 constraints.
# Solved with optimal value: 44.34166203101602 out of 64.
# Finished post-processing solution.
# Solving instance with n=353, k=94.
# Pruned 235 intervals. Solving with n=118, k=63.
# Solving with 417 constraints.
# Solved with optimal value: 43.56429922265503 out of 63.
# Finished post-processing solution.
# Solving instance with n=353, k=95.
# Pruned 233 intervals. Solving with n=120, k=64.
# Solving with 424 constraints.
# Solved with optimal value: 44.58651219008792 out of 64.
# Finished post-processing solution.
# Solving instance with n=353, k=96.
# Pruned 232 intervals. Solving with n=121, k=64.
# Solving with 427 constraints.
# Solved with optimal value: 44.66797720718324 out of 64.
# Finished post-processing solution.
# Solving instance with n=353, k=97.
# Pruned 233 intervals. Solving with n=120, k=64.
# Solving with 424 constraints.
# Solved with optimal value: 44.81535763849523 out of 64.
# Finished post-processing solution.
# Solving instance with n=353, k=98.
# Pruned 233 intervals. Solving with n=120, k=65.
# Solving with 425 constraints.
# Solved with optimal value: 45.94851120201347 out of 65.
# Finished post-processing solution.
# Solving instance with n=353, k=99.
# Pruned 233 intervals. Solving with n=120, k=66.
# Solving with 426 constraints.
# Solved with optimal value: 46.926868935711965 out of 66.
# Finished post-processing solution.
# Solving instance with n=353, k=100.
# Pruned 233 intervals. Solving with n=120, k=67.
# Solving with 427 constraints.
# Solved with optimal value: 47.89340805951862 out of 67.
# Finished post-processing solution.
# Solving instance with n=353, k=101.
# Pruned 235 intervals. Solving with n=118, k=66.
# Solving with 420 constraints.
# Solved with optimal value: 46.99999999863226 out of 66.
# Finished post-processing solution.
# Solving instance with n=353, k=102.
# Pruned 229 intervals. Solving with n=124, k=67.
# Solving with 439 constraints.
# Solved with optimal value: 48.041487852763254 out of 67.
# Finished post-processing solution.
# Solving instance with n=353, k=103.
# Pruned 224 intervals. Solving with n=129, k=67.
# Solving with 646 constraints.
# Solved with optimal value: 48.17147194609083 out of 67.
# Finished post-processing solution.
# Solving instance with n=353, k=104.
# Pruned 225 intervals. Solving with n=128, k=67.
# Solving with 451 constraints.
# Solved with optimal value: 48.33792915597292 out of 67.
# Finished post-processing solution.
# Solving instance with n=353, k=105.
# Pruned 224 intervals. Solving with n=129, k=67.
# Solving with 454 constraints.
# Solved with optimal value: 48.11431998468093 out of 67.
# Finished post-processing solution.
# Solving instance with n=353, k=106.
# Pruned 221 intervals. Solving with n=132, k=68.
# Solving with 464 constraints.
# Solved with optimal value: 48.89092736278669 out of 68.
# Finished post-processing solution.

# %%
print(verify_posthoc_validity(intervals90, p))
valid = [verify_posthoc_validity(intervals90, p) for p in pseq]
1. * sum(valid) / len(valid)
# Out:
# True
# 1.0

# %%
n_top = len(top)
pct_swiss = np.round((evaluate_p([(l/2., u/2.) for (l,u) in intervals90], p_swiss, k) - n_top) / (k-n_top), 3)
pct_opt = np.round((evaluate_p([(l/2., u/2.) for (l,u) in intervals90], p, k) - n_top) / (k-n_top), 3)
pct_opt_monotonic = np.round((evaluate_p([(l/2., u/2.) for (l,u) in intervals90], pseq[-1], k) - n_top) / (k-n_top), 3)
pct_topk = np.round((evaluate_p([(l/2., u/2.) for (l,u) in intervals90], [1]*k+[0]*(n-k), k) - n_top) / (k-n_top), 3)

print(f"Always select {n_top}, {k-n_top} intervals left to optimize.")
print("Proportion of top-k intervals selected in worst case:")
print(f"Optimal: {pct_opt}")
print(f"Optimal w/ Monotonic: {pct_opt_monotonic}")
print(f"Swiss: {pct_swiss}")
print(f"Top-k: {pct_topk}")
# Out:
# Always select 38, 68 intervals left to optimize.
# Proportion of top-k intervals selected in worst case:
# Optimal: 0.721
# Optimal w/ Monotonic: 0.719
# Swiss: 0.668
# Top-k: 0.618

# %% [markdown]
# ### NeurIPS 2024 (Min-Max Review Score Intervals)

# %%
df = pd.read_csv('data/ConferenceReviewData/neurips2024_data/neurips2024_reviews.csv')
df = df[df.decision != 'Reject'].reset_index(drop=True)
ratings = df.groupby('paper_id').agg({'rating': ['max', 'mean', 'min', 'count'], 'decision': 'max'}).reset_index()
ratings.columns = ['paper_id', 'rating_max', 'rating_mean', 'rating_min', 'num_reviews', 'decision']
# rename Accept (poster) to Poster and Accept (oral) or Accept (spotlight) to Spotlight/Oral
ratings['decision'] = ratings['decision'].replace({'Accept (poster)': 'Poster', 'Accept (oral)': 'Spotlight/Oral', 'Accept (spotlight)': 'Spotlight/Oral'})
ratings['decision'].value_counts()
# Out:
# decision
# Poster            3648
# Spotlight/Oral     387
# Name: count, dtype: int64

# %%
intervals = list(zip(ratings['rating_min'], ratings['rating_max']))
x = list(ratings['rating_mean'])
decisions = ratings['decision']

# %%
k = 387

# %%
pruned, top, bottom = prune_instance(intervals, k)
pruned_intervals = [intervals[i] for i in pruned]
print("Accept {} intervals".format(len(top)))
print("Reject {} intervals".format(len(bottom)))
print("Remaining {} intervals".format(len(pruned)))
n_partitions = len(partition_intervals(intervals))
n_partitions_pruned = len(partition_intervals(pruned_intervals))
print("Number of partitions: {}".format(n_partitions))
print("Number of partitions pruned: {}".format(n_partitions_pruned))
# Out:
# Accept 0 intervals
# Reject 71 intervals
# Remaining 3964 intervals
# Number of partitions: 3
# Number of partitions pruned: 2

# %%
v, p = solve_instance_unordered(intervals, k, k)
p_swiss = swiss_nsf(intervals, x, k)
# Out:
# Solving instance with n=4035, k=387.
# Pruned 71 intervals. Solving with n=3964, k=387.
# Partitioned intervals into 2 subsets.

# %% [markdown]
# ### NeurIPS 2024 ("Bootstrapped" Intervals)

# %%
df = pd.read_csv()
df = df[df.decision != 'Reject'].reset_index(drop=True)
ratings = df.groupby('paper_id').agg({'rating': list, 'decision': 'max'}).reset_index()
ratings['decision'] = ratings['decision'].replace({'Accept (poster)': 'Poster', 'Accept (oral)': 'Spotlight/Oral', 'Accept (spotlight)': 'Spotlight/Oral'})

# %%
def get_interval(lst):
    means = []
    for i in range(len(lst)):
        temp_lst = lst[:i] + lst[i+1:]
        mean = 1. * sum(temp_lst) / len(temp_lst)
        means.append(mean)
    return min(means), max(means)

# %%
intervals = ratings['rating'].apply(get_interval)
x = ratings['rating'].apply(np.mean)
decision = ratings['decision']

# %%
pruned, top, bottom = prune_instance(intervals, k)
pruned_intervals = [intervals[i] for i in pruned]
print("Accept {} intervals".format(len(top)))
print("Reject {} intervals".format(len(bottom)))
print("Remaining {} intervals".format(len(pruned)))
n_partitions = len(partition_intervals(intervals))
n_partitions_pruned = len(partition_intervals(pruned_intervals))
print("Number of partitions: {}".format(n_partitions))
print("Number of partitions pruned: {}".format(n_partitions_pruned))
# Out:
# Accept 21 intervals
# Reject 2396 intervals
# Remaining 1618 intervals
# Number of partitions: 9
# Number of partitions pruned: 2

# %% [markdown]
# ## Compare Approaches

# %%
k = 106
T = k

# %%
def summarize_p(p):
    # Num accepted
    p_round = np.round(p, 2)
    num_accepted = np.sum(p_round == 1)
    num_rejected = np.sum(p_round == 0)
    print(f"Accepted: {num_accepted} intervals")
    print(f"Randomized: {len(p) - (num_accepted + num_rejected)} intervals")
    print(f"Rejected: {num_rejected} intervals")

    print("")

    p_counts = np.unique(p_round, return_counts=True)
    # print count of each p_i in decreasing order of p_i
    for i in list(range(len(p_counts[0])))[::-1]:
        print(f"p = {p_counts[0][i]}: {p_counts[1][i]} intervals")

# %%
summarize_p(p_swiss)
# Out:
# Accepted: 93 intervals
# Randomized: 25 intervals
# Rejected: 234 intervals
#
# p = 1.0: 93 intervals
# p = 0.52: 25 intervals
# p = 0.0: 234 intervals

# %%
v, p = solve_instance_ordered([(l/2., u/2.) for (l,u) in intervals], T, k, list(range(n)), lex_order_p=1)
# Out:
# Pruned 303 intervals. Solving with n=49, k=22.
# Solving with 120 constraints.
# Solved for lexicographic ordering on p.
# Solved with optimal value: 13.732057416178245 out of 22.

# %%
summarize_p(p=p)
# Out:
# Accepted: 95 intervals
# Randomized: 28 intervals
# Rejected: 229 intervals
#
# p = 1.0: 95 intervals
# p = 0.96: 2 intervals
# p = 0.53: 1 intervals
# p = 0.48: 17 intervals
# p = 0.05: 6 intervals
# p = 0.01: 2 intervals
# p = 0.0: 229 intervals

# %%
pct_swiss = np.round(evaluate_p([(l/2., u/2.) for (l,u) in intervals],p_swiss, k) / T, 3)
pct_opt = np.round(evaluate_p([(l/2., u/2.) for (l,u) in intervals], p, k) / T, 3)
pct_topk = np.round(evaluate_p([(l/2., u/2.) for (l,u) in intervals],[1]*k+[0]*(n-k), k) / T, 3)

print("Proportion of top-k intervls selected in worst case:")
print(f"Optimal: {pct_opt}")
print(f"Swiss: {pct_swiss}")
print(f"Top-k: {pct_topk}")
# Out:
# Proportion of top-k intervls selected in worst case:
# Optimal: 0.922
# Swiss: 0.907
# Top-k: 0.887

# %%
k = 53
T = k

# %%
p_swiss = swiss_nsf(intervals, means, k)
v, p = solve_instance_ordered([(l/2., u/2.) for (l,u) in intervals], T, k, list(range(n)), lex_order_p=1)
# Out:
# Pruned 324 intervals. Solving with n=28, k=13.
# Solving with 69 constraints.
# Solved for lexicographic ordering on p.
# Solved with optimal value: 8.239999998817677 out of 13.

# %%
summarize_p(p_swiss)
# Out:
# Accepted: 45 intervals
# Randomized: 14 intervals
# Rejected: 293 intervals
#
# p = 1.0: 45 intervals
# p = 0.57: 14 intervals
# p = 0.0: 293 intervals

# %%
summarize_p(p)
# Out:
# Accepted: 44 intervals
# Randomized: 18 intervals
# Rejected: 290 intervals
#
# p = 1.0: 44 intervals
# p = 0.97: 1 intervals
# p = 0.94: 1 intervals
# p = 0.93: 1 intervals
# p = 0.92: 1 intervals
# p = 0.48: 9 intervals
# p = 0.44: 2 intervals
# p = 0.02: 1 intervals
# p = 0.01: 2 intervals
# p = 0.0: 290 intervals

# %%
pct_swiss = np.round(evaluate_p([(l/2., u/2.) for (l,u) in intervals],p_swiss, k) / T, 3)
pct_opt = np.round(evaluate_p([(l/2., u/2.) for (l,u) in intervals], p, k) / T, 3)
pct_topk = np.round(evaluate_p([(l/2., u/2.) for (l,u) in intervals],[1]*k+[0]*(n-k), k) / T, 3)

print("Proportion of top-k intervls selected in worst case:")
print(f"Optimal: {pct_opt}")
print(f"Swiss: {pct_swiss}")
print(f"Top-k: {pct_topk}")
# Out:
# Proportion of top-k intervls selected in worst case:
# Optimal: 0.91
# Swiss: 0.892
# Top-k: 0.868

# %% [markdown]
# ## Check Monotonicity in k

# %%
# check monotonoicity of swiss_nsf
p_swiss_prev = swiss_nsf(intervals, means, 1)

for k in range(2,200):
    p_swiss = swiss_nsf(intervals, means, k)
    if np.any(p_swiss_prev > p_swiss):
        print(f"Swiss NSF is not monotonic for k={k}")
        break
    p_swiss_prev = p_swiss
# Out:
# Swiss NSF is not monotonic for k=83

# %%
summarize_p(swiss_nsf(intervals, means, 82))
# Out:
# p = 1.0: 72 intervals
# p = 0.53: 19 intervals
# p = 0.0: 261 intervals

# %%
summarize_p(swiss_nsf(intervals, means, 83))
# Out:
# p = 1.0: 72 intervals
# p = 0.52: 21 intervals
# p = 0.0: 259 intervals

# %%
# check monotonoicity of our method with k=T
p_opt_prev = solve_instance_ordered(intervals, 1, 1, list(range(n)), lex_order_p=1, verbose=False)[1]

for k in range(2,200):
    p_opt = solve_instance_ordered(intervals, k, k, list(range(n)), lex_order_p=1, verbose=False)[1]
    if np.any(p_opt_prev > p_opt):
        print(f"Our method with T=k is not monotonic for k={k}")
        break
    p_opt_prev = p_opt
# Out:
# Our method with T=k is not monotonic for k=3

# %%
summarize_p(p_opt_prev)
# Out:
# p = 0.49: 1 intervals
# p = 0.33: 4 intervals
# p = 0.17: 1 intervals
# p = 0.0: 346 intervals

# %%
summarize_p(p_opt)
# Out:
# p = 1.0: 1 intervals
# p = 0.5: 4 intervals
# p = 0.0: 347 intervals

# %%
# check monotonoicity of our method with T constant 
T=106

p_opt_prev = solve_instance_ordered(intervals, T, 1, list(range(n)), lex_order_p=-1, verbose=False)[1]

for k in range(2,200):
    p_opt = solve_instance_ordered(intervals, T, k, list(range(n)), lex_order_p=-1, verbose=False)[1]
    if np.any(p_opt_prev > p_opt):
        print(f"Our method with T=k is not monotonic for k={k}")
        break
    p_opt_prev = p_opt
# Out:
# Our method with T=k is not monotonic for k=87

# %%
summarize_p(p_opt)
# Out:
# p = 1.0: 84 intervals
# p = 0.67: 1 intervals
# p = 0.48: 1 intervals
# p = 0.21: 2 intervals
# p = 0.15: 1 intervals
# p = 0.12: 1 intervals
# p = 0.11: 4 intervals
# p = 0.05: 13 intervals
# p = 0.02: 1 intervals
# p = 0.0: 244 intervals

# %%
summarize_p(p_opt_prev)
# Out:
# p = 1.0: 84 intervals
# p = 0.45: 1 intervals
# p = 0.32: 1 intervals
# p = 0.14: 2 intervals
# p = 0.1: 1 intervals
# p = 0.08: 1 intervals
# p = 0.07: 4 intervals
# p = 0.04: 13 intervals
# p = 0.01: 1 intervals
# p = 0.0: 244 intervals
